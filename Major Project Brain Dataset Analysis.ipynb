# %%
import os
import matplotlib.pyplot as plt

# Path to the directory containing the class folders
directory = r"D:\brain tumor\Training"

# Initialize a dictionary to store the counts for each class
class_counts = {}

# Iterate through the class folders
for class_name in os.listdir(directory):
    class_path = os.path.join(directory, class_name)
    if os.path.isdir(class_path):
        # Count the number of files in the class folder
        file_count = len(os.listdir(class_path))
        class_counts[class_name] = file_count

# Create a pie chart
plt.figure(figsize=(5, 5))
plt.pie(class_counts.values(), labels=class_counts.keys(), autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title('Distribution of Image Counts in Each Class in Classification Dataset')
plt.show()

# %%
import os
import matplotlib.pyplot as plt

# Path to the directory containing the class folders
directory = r"E:\Brain tumor seg"

# Initialize a dictionary to store the counts for each class
class_counts = {}

# Iterate through the class folders
for class_name in os.listdir(directory):
    class_path = os.path.join(directory, class_name)
    if os.path.isdir(class_path):
        # Count the number of files in the class folder
        file_count = len(os.listdir(class_path))
        class_counts[class_name] = file_count

# Create a pie chart
plt.figure(figsize=(5, 5))
plt.pie(class_counts.values(), labels=class_counts.keys(), autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title('Distribution of Image Counts in Each Class in Classification Dataset')
plt.show()
