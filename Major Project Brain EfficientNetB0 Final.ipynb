# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet import EfficientNetB0, preprocess_input
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# Out:
# WARNING:tensorflow:From C:\Users\asus\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Paths to the datasets
base_path = "D:\\brain tumor\\Training"

# %%
# Parameters
img_size = (224, 224)  # Standard input size for EfficientNetB0
batch_size = 32

# %%
# Load and split the data into training, validation, and testing sets
files = []
labels = []
for label in os.listdir(base_path):
    class_dir = os.path.join(base_path, label)
    if os.path.isdir(class_dir):
        files.extend([os.path.join(class_dir, f) for f in os.listdir(class_dir)])
        labels.extend([label] * len(os.listdir(class_dir)))

# %%
# Split data into training+validation and testing sets first
train_valid_files, test_files, train_valid_labels, test_labels = train_test_split(
    files, labels, test_size=0.15, random_state=42
)

# Split training+validation into training and validation sets
train_files, valid_files, train_labels, valid_labels = train_test_split(
    train_valid_files, train_valid_labels, test_size=0.1765, random_state=42  # 0.1765 is approximately 15% of 85%
)

# %%
train_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=40,             # randomly rotate images in the range (degrees, 0 to 180)
    width_shift_range=0.2,         # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.2,        # randomly shift images vertically (fraction of total height)
    shear_range=0.2,               # apply shearing transformation
    zoom_range=0.2,                # randomly zoom into images
    horizontal_flip=True,          # randomly flip images horizontally
    fill_mode='nearest'            # strategy for filling in newly created pixels, which can appear after a rotation or a width/height shift
).flow_from_dataframe(
    pd.DataFrame({'filepaths': train_files, 'labels': train_labels}),
    x_col='filepaths',
    y_col='labels',
    target_size=img_size,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=True,
    batch_size=batch_size
)
valid_gen = ImageDataGenerator(preprocessing_function=preprocess_input).flow_from_dataframe(
    pd.DataFrame({'filepaths': valid_files, 'labels': valid_labels}),
    x_col='filepaths',
    y_col='labels',
    target_size=img_size,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=False,
    batch_size=batch_size
)

test_gen = ImageDataGenerator(preprocessing_function=preprocess_input).flow_from_dataframe(
    pd.DataFrame({'filepaths': test_files, 'labels': test_labels}),
    x_col='filepaths',
    y_col='labels',
    target_size=img_size,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=False,
    batch_size=batch_size
)
# Out:
# Found 4915 validated image filenames belonging to 4 classes.
# Found 1054 validated image filenames belonging to 4 classes.
# Found 1054 validated image filenames belonging to 4 classes.

# %%
# Initialize the EfficientNetB0 model
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=img_size + (3,))

# Freeze the base model
for layer in base_model.layers:
    layer.trainable = False

# %%
# Create the model's head (top layers)
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(len(set(train_labels)), activation='softmax')(x)

# %%
# Construct the final model
model = Model(inputs=base_model.input, outputs=predictions)

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# Setup callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min')
model_checkpoint = ModelCheckpoint('EfficinetB0_Brain1.keras', monitor='val_loss', save_best_only=True, mode='min', verbose=1)

# %%
# Train the model
history=model.fit(train_gen, 
          validation_data=valid_gen, 
          epochs=50,
          steps_per_epoch=len(train_gen), 
          validation_steps=len(valid_gen),
          callbacks=[early_stopping, model_checkpoint])
# Out:
# Epoch 1/50
# 154/154 [==============================] - ETA: 0s - loss: 0.4955 - accuracy: 0.8045
# Epoch 1: val_loss improved from inf to 0.28591, saving model to EfficinetB0_Brain1.keras
# 154/154 [==============================] - 82s 513ms/step - loss: 0.4955 - accuracy: 0.8045 - val_loss: 0.2859 - val_accuracy: 0.8824
# Epoch 2/50
# 154/154 [==============================] - ETA: 0s - loss: 0.3196 - accuracy: 0.8779
# Epoch 2: val_loss improved from 0.28591 to 0.22676, saving model to EfficinetB0_Brain1.keras
# 154/154 [==============================] - 80s 516ms/step - loss: 0.3196 - accuracy: 0.8779 - val_loss: 0.2268 - val_accuracy: 0.9108
# Epoch 3/50
# 154/154 [==============================] - ETA: 0s - loss: 0.2578 - accuracy: 0.9017
# Epoch 3: val_loss improved from 0.22676 to 0.19590, saving model to EfficinetB0_Brain1.keras
# 154/154 [==============================] - 100s 648ms/step - loss: 0.2578 - accuracy: 0.9017 - val_loss: 0.1959 - val_accuracy: 0.9222
# Epoch 4/50
# 154/154 [==============================] - ETA: 0s - loss: 0.2223 - accuracy: 0.9166
# Epoch 4: val_loss improved from 0.19590 to 0.18375, saving model to EfficinetB0_Brain1.keras
# 154/154 [==============================] - 105s 678ms/step - loss: 0.2223 - accuracy: 0.9166 - val_loss: 0.1837 - val_accuracy: 0.9298
# Epoch 5/50
# 154/154 [==============================] - ETA: 0s - loss: 0.2056 - accuracy: 0.9225
# Epoch 5: val_loss improved from 0.18375 to 0.17694, saving model to EfficinetB0_Brain1.keras
# 154/154 [==============================] - 103s 671ms/step - loss: 0.2056 - accuracy: 0.9225 - val_loss: 0.1769 - val_accuracy: 0.9298
# Epoch 6/50
# 154/154 [==============================] - ETA: 0s - loss: 0.1885 - accuracy: 0.9288
# Epoch 6: val_loss improved from 0.17694 to 0.15740, saving model to EfficinetB0_Brain1.keras
# 154/154 [==============================] - 105s 680ms/step - loss: 0.1885 - accuracy: 0.9288 - val_loss: 0.1574 - val_accuracy: 0.9431
# Epoch 7/50
# 154/154 [==============================] - ETA: 0s - loss: 0.1659 - accuracy: 0.9329
# Epoch 7: val_loss improved from 0.15740 to 0.15226, saving model to EfficinetB0_Brain1.keras
# 154/154 [==============================] - 102s 662ms/step - loss: 0.1659 - accuracy: 0.9329 - val_loss: 0.1523 - val_accuracy: 0.9431
# Epoch 8/50
# 154/154 [==============================] - ETA: 0s - loss: 0.1522 - accuracy: 0.9420
# Epoch 8: val_loss improved from 0.15226 to 0.14222, saving model to EfficinetB0_Brain1.keras
# 154/154 [==============================] - 100s 651ms/step - loss: 0.1522 - accuracy: 0.9420 - val_loss: 0.1422 - val_accuracy: 0.9469
# Epoch 9/50
# 154/154 [==============================] - ETA: 0s - loss: 0.1445 - accuracy: 0.9457
# Epoch 9: val_loss did not improve from 0.14222
# 154/154 [==============================] - 101s 657ms/step - loss: 0.1445 - accuracy: 0.9457 - val_loss: 0.1628 - val_accuracy: 0.9393
# Epoch 10/50
# 154/154 [==============================] - ETA: 0s - loss: 0.1374 - accuracy: 0.9481
# Epoch 10: val_loss did not improve from 0.14222
# 154/154 [==============================] - 101s 656ms/step - loss: 0.1374 - accuracy: 0.9481 - val_loss: 0.1438 - val_accuracy: 0.9431
# Epoch 11/50
# 154/154 [==============================] - ETA: 0s - loss: 0.1266 - accuracy: 0.9534
# Epoch 11: val_loss improved from 0.14222 to 0.12960, saving model to EfficinetB0_Brain1.keras
# 154/154 [==============================] - 100s 652ms/step - loss: 0.1266 - accuracy: 0.9534 - val_loss: 0.1296 - val_accuracy: 0.9526
# Epoch 12/50
# 154/154 [==============================] - ETA: 0s - loss: 0.1141 - accuracy: 0.9573
# Epoch 12: val_loss did not improve from 0.12960
# 154/154 [==============================] - 99s 640ms/step - loss: 0.1141 - accuracy: 0.9573 - val_loss: 0.1368 - val_accuracy: 0.9497
# Epoch 13/50
# 154/154 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9597
# Epoch 13: val_loss did not improve from 0.12960
# 154/154 [==============================] - 100s 649ms/step - loss: 0.1065 - accuracy: 0.9597 - val_loss: 0.1385 - val_accuracy: 0.9516
# Epoch 14/50
# 154/154 [==============================] - ETA: 0s - loss: 0.0921 - accuracy: 0.9654
# Epoch 14: val_loss did not improve from 0.12960
# 154/154 [==============================] - 99s 642ms/step - loss: 0.0921 - accuracy: 0.9654 - val_loss: 0.1539 - val_accuracy: 0.9488
# Epoch 15/50
# 154/154 [==============================] - ETA: 0s - loss: 0.1078 - accuracy: 0.9615
# Epoch 15: val_loss improved from 0.12960 to 0.11070, saving model to EfficinetB0_Brain1.keras
# 154/154 [==============================] - 99s 643ms/step - loss: 0.1078 - accuracy: 0.9615 - val_loss: 0.1107 - val_accuracy: 0.9602
# Epoch 16/50
# 154/154 [==============================] - ETA: 0s - loss: 0.0887 - accuracy: 0.9648
# Epoch 16: val_loss did not improve from 0.11070
# 154/154 [==============================] - 98s 638ms/step - loss: 0.0887 - accuracy: 0.9648 - val_loss: 0.1185 - val_accuracy: 0.9545
# Epoch 17/50
# 154/154 [==============================] - ETA: 0s - loss: 0.0918 - accuracy: 0.9658
# Epoch 17: val_loss improved from 0.11070 to 0.10370, saving model to EfficinetB0_Brain1.keras
# 154/154 [==============================] - 94s 608ms/step - loss: 0.0918 - accuracy: 0.9658 - val_loss: 0.1037 - val_accuracy: 0.9620
# Epoch 18/50
# 154/154 [==============================] - ETA: 0s - loss: 0.0832 - accuracy: 0.9683
# Epoch 18: val_loss did not improve from 0.10370
# 154/154 [==============================] - 80s 522ms/step - loss: 0.0832 - accuracy: 0.9683 - val_loss: 0.1077 - val_accuracy: 0.9535
# Epoch 19/50
# 154/154 [==============================] - ETA: 0s - loss: 0.0851 - accuracy: 0.9697
# Epoch 19: val_loss did not improve from 0.10370
# 154/154 [==============================] - 81s 528ms/step - loss: 0.0851 - accuracy: 0.9697 - val_loss: 0.1293 - val_accuracy: 0.9535
# Epoch 20/50
# 154/154 [==============================] - ETA: 0s - loss: 0.0837 - accuracy: 0.9687
# Epoch 20: val_loss did not improve from 0.10370
# 154/154 [==============================] - 81s 525ms/step - loss: 0.0837 - accuracy: 0.9687 - val_loss: 0.1232 - val_accuracy: 0.9554
# Epoch 21/50
# 154/154 [==============================] - ETA: 0s - loss: 0.0833 - accuracy: 0.9691
# Epoch 21: val_loss did not improve from 0.10370
# 154/154 [==============================] - 82s 533ms/step - loss: 0.0833 - accuracy: 0.9691 - val_loss: 0.1055 - val_accuracy: 0.9620
# Epoch 22/50
# 154/154 [==============================] - ETA: 0s - loss: 0.0767 - accuracy: 0.9701
# Epoch 22: val_loss improved from 0.10370 to 0.09400, saving model to EfficinetB0_Brain1.keras
# 154/154 [==============================] - 82s 535ms/step - loss: 0.0767 - accuracy: 0.9701 - val_loss: 0.0940 - val_accuracy: 0.9658
# Epoch 23/50
# 154/154 [==============================] - ETA: 0s - loss: 0.0703 - accuracy: 0.9736
# Epoch 23: val_loss did not improve from 0.09400
# 154/154 [==============================] - 84s 546ms/step - loss: 0.0703 - accuracy: 0.9736 - val_loss: 0.1139 - val_accuracy: 0.9620
# Epoch 24/50
# 154/154 [==============================] - ETA: 0s - loss: 0.0699 - accuracy: 0.9740
# Epoch 24: val_loss did not improve from 0.09400
# 154/154 [==============================] - 82s 532ms/step - loss: 0.0699 - accuracy: 0.9740 - val_loss: 0.1104 - val_accuracy: 0.9564
# Epoch 25/50
# 154/154 [==============================] - ETA: 0s - loss: 0.0682 - accuracy: 0.9752
# Epoch 25: val_loss improved from 0.09400 to 0.09387, saving model to EfficinetB0_Brain1.keras
# 154/154 [==============================] - 82s 531ms/step - loss: 0.0682 - accuracy: 0.9752 - val_loss: 0.0939 - val_accuracy: 0.9630
# Epoch 26/50
# 154/154 [==============================] - ETA: 0s - loss: 0.0677 - accuracy: 0.9733
# Epoch 26: val_loss did not improve from 0.09387
# 154/154 [==============================] - 81s 528ms/step - loss: 0.0677 - accuracy: 0.9733 - val_loss: 0.0986 - val_accuracy: 0.9668
# Epoch 27/50
# 154/154 [==============================] - ETA: 0s - loss: 0.0589 - accuracy: 0.9782
# Epoch 27: val_loss improved from 0.09387 to 0.09345, saving model to EfficinetB0_Brain1.keras
# 154/154 [==============================] - 82s 530ms/step - loss: 0.0589 - accuracy: 0.9782 - val_loss: 0.0935 - val_accuracy: 0.9602
# Epoch 28/50
# 154/154 [==============================] - ETA: 0s - loss: 0.0672 - accuracy: 0.9748
# Epoch 28: val_loss improved from 0.09345 to 0.09218, saving model to EfficinetB0_Brain1.keras
# 154/154 [==============================] - 81s 528ms/step - loss: 0.0672 - accuracy: 0.9748 - val_loss: 0.0922 - val_accuracy: 0.9687
# Epoch 29/50
# 154/154 [==============================] - ETA: 0s - loss: 0.0612 - accuracy: 0.9772
# Epoch 29: val_loss did not improve from 0.09218
# 154/154 [==============================] - 81s 525ms/step - loss: 0.0612 - accuracy: 0.9772 - val_loss: 0.1105 - val_accuracy: 0.9620
# Epoch 30/50
# 154/154 [==============================] - ETA: 0s - loss: 0.0691 - accuracy: 0.9754
# Epoch 30: val_loss did not improve from 0.09218
# 154/154 [==============================] - 82s 530ms/step - loss: 0.0691 - accuracy: 0.9754 - val_loss: 0.1241 - val_accuracy: 0.9554
# Epoch 31/50
# 154/154 [==============================] - ETA: 0s - loss: 0.0551 - accuracy: 0.9790
# Epoch 31: val_loss did not improve from 0.09218
# 154/154 [==============================] - 81s 526ms/step - loss: 0.0551 - accuracy: 0.9790 - val_loss: 0.1116 - val_accuracy: 0.9602
# Epoch 32/50
# 154/154 [==============================] - ETA: 0s - loss: 0.0549 - accuracy: 0.9795
# Epoch 32: val_loss did not improve from 0.09218
# 154/154 [==============================] - 81s 525ms/step - loss: 0.0549 - accuracy: 0.9795 - val_loss: 0.1353 - val_accuracy: 0.9592
# Epoch 33/50
# 154/154 [==============================] - ETA: 0s - loss: 0.0526 - accuracy: 0.9788
# Epoch 33: val_loss did not improve from 0.09218
# 154/154 [==============================] - 81s 525ms/step - loss: 0.0526 - accuracy: 0.9788 - val_loss: 0.1363 - val_accuracy: 0.9602
# Epoch 34/50
# 154/154 [==============================] - ETA: 0s - loss: 0.0542 - accuracy: 0.9819
# Epoch 34: val_loss did not improve from 0.09218
# 154/154 [==============================] - 81s 526ms/step - loss: 0.0542 - accuracy: 0.9819 - val_loss: 0.1280 - val_accuracy: 0.9535
# Epoch 35/50
# 154/154 [==============================] - ETA: 0s - loss: 0.0513 - accuracy: 0.9801
# Epoch 35: val_loss did not improve from 0.09218
# 154/154 [==============================] - 101s 659ms/step - loss: 0.0513 - accuracy: 0.9801 - val_loss: 0.1233 - val_accuracy: 0.9630
# Epoch 36/50
# 154/154 [==============================] - ETA: 0s - loss: 0.0496 - accuracy: 0.9821
# Epoch 36: val_loss did not improve from 0.09218
# 154/154 [==============================] - 101s 654ms/step - loss: 0.0496 - accuracy: 0.9821 - val_loss: 0.1086 - val_accuracy: 0.9592
# Epoch 37/50
# 154/154 [==============================] - ETA: 0s - loss: 0.0434 - accuracy: 0.9839
# Epoch 37: val_loss did not improve from 0.09218
# 154/154 [==============================] - 99s 642ms/step - loss: 0.0434 - accuracy: 0.9839 - val_loss: 0.1037 - val_accuracy: 0.9687
# Epoch 38/50
# 154/154 [==============================] - ETA: 0s - loss: 0.0467 - accuracy: 0.9825
# Epoch 38: val_loss did not improve from 0.09218
# 154/154 [==============================] - 98s 638ms/step - loss: 0.0467 - accuracy: 0.9825 - val_loss: 0.1120 - val_accuracy: 0.9639
# Epoch 38: early stopping

# %%
#Training and validation Accuracy and loss graph

# %%
import matplotlib.pyplot as plt

# Extracting data from the history object
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# Finding the best epoch (the one with the lowest validation loss)
best_epoch = val_loss.index(min(val_loss)) + 1

# Plotting training and validation accuracy
plt.figure(figsize=(14, 5))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, label='Training Accuracy', color='blue')
plt.plot(epochs, val_acc, label='Validation Accuracy', color='orange')
plt.scatter(best_epoch, val_acc[best_epoch - 1], color='red', zorder=5)  # Mark the best epoch
plt.text(best_epoch, val_acc[best_epoch - 1], f'Best epoch = {best_epoch}', color='red', ha='center', va='bottom')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, label='Training Loss', color='blue')
plt.plot(epochs, val_loss, label='Validation Loss', color='orange')
plt.scatter(best_epoch, val_loss[best_epoch - 1], color='red', zorder=5)  # Mark the best epoch
plt.text(best_epoch, val_loss[best_epoch - 1], f'Best epoch = {best_epoch}', color='red', ha='center', va='top')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
#Evaluation on test data

# %%
from tensorflow.keras.models import load_model
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# %%
model = load_model('EfficinetB0_Brain1.keras')

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(test_gen, steps=len(test_gen))

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)


# Predict the test set
test_preds = model.predict(test_gen, steps=len(test_gen))

# Convert predictions from one-hot encoded vectors to class indices
predicted_classes = np.argmax(test_preds, axis=1)

# Retrieve true class labels from the test generator
true_classes = test_gen.classes

# Class labels (ensure these are in the same order as the generator's classes)
class_labels = list(test_gen.class_indices.keys())

# Confusion Matrix
conf_matrix = confusion_matrix(true_classes, predicted_classes)

# Plot Confusion Matrix
plt.figure(figsize=(4, 4))
sns.set(font_scale=1.2)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix of EfficintNetB0')
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.show()

# Classification Report
class_report = classification_report(true_classes, predicted_classes, target_names=class_labels)

print("\nClassification Report:")
print(class_report)
# Out:
# 33/33 [==============================] - 20s 551ms/step - loss: 0.1025 - accuracy: 0.9611
# Test Loss: 0.10252630710601807
# Test Accuracy: 0.9611005783081055
# 33/33 [==============================] - 16s 448ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#       glioma       0.96      0.95      0.96       258
#   meningioma       0.92      0.93      0.93       247
#      notumor       0.99      0.97      0.98       292
#    pituitary       0.98      0.98      0.98       257
#
#     accuracy                           0.96      1054
#    macro avg       0.96      0.96      0.96      1054
# weighted avg       0.96      0.96      0.96      1054
